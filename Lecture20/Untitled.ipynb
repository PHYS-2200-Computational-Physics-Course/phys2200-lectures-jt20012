# %%
using PyPlot
M(t) = 1 .- 1.904e-6 .* t
t = 0:525210 
plot(t, M(t))
xlabel("Time (years)")
ylabel("Mass (Solar Mass)")
title("M = 1 - 1.904e-6 * t")
grid(true)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
